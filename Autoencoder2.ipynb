# %%
# %matplotlib inline
import pandas as pd
import glob
import os
import matplotlib.pyplot as plt
import numpy as np
import keras
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Activation, Dropout, Attention, BatchNormalization
from tensorflow.keras import optimizers, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import layers
from keras.models import Model, load_model
from tensorflow.keras.optimizers import SGD
import pprint
from datetime import datetime
import matplotlib
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import KFold
from sklearn import preprocessing
from sklearn.metrics import r2_score

import sklearn
import math
from numpy.random import seed

from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error
from scikeras.wrappers import KerasRegressor



seed_value = 10
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
print('pd.__version__: ',pd.__version__)
print('np.__version__: ',np.__version__)
print('keras.__version__: ',keras.__version__)
print('tf.__version__: ',tf.__version__)
print('matplotlib.__version__: ',matplotlib.__version__)
# Out:
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# pd.__version__:  2.2.3
# np.__version__:  1.26.4
# keras.__version__:  3.7.0
# tf.__version__:  2.18.0
# matplotlib.__version__:  3.9.2

# %%
import os

# Define the directory you want to list
directory = 'C:/Backup - Oct 2024/Oct-2023 Backup/Users/msalmaniaran/PhD/Results-data/Reconfigurable-patch - Copy'

# List all files and directories in the specified directory
all_files = os.listdir(directory)

# Filter out only the files
files = [f for f in all_files if os.path.isfile(os.path.join(directory, f))]
files.sort()
# Print the list of files
for file in files:
    print(file)

dict_files = {i: files[i] for i in range(len(files))}
print(dict_files)
# Out:
# AllDiode-OFF-Alpha sweep.csv
# AllDiode-OFF-fx sweep.csv
# AllDiode-OFF-fy sweep.csv
# AllDiode-OFF-l sweep.csv
# AllDiode-OFF-lextention sweep.csv
# AllDiode-OFF-lh sweep.csv
# AllDiode-OFF-lr sweep.csv
# AllDiode-OFF-lv sweep.csv
# AllDiode-OFF-offset1 sweep.csv
# AllDiode-OFF-pr sweep.csv
# AllDiode-OFF-pr2 sweep.csv
# AllDiode-OFF-w sweep.csv
# AllDiode-OFF-wr sweep.csv
# AllDiode-OFF-wu sweep.csv
# AllDiode-ON-Alpha sweep.csv
# AllDiode-ON-fx sweep.csv
# AllDiode-ON-fy sweep.csv
# AllDiode-ON-l sweep.csv
# AllDiode-ON-lextention sweep.csv
# AllDiode-ON-lh sweep.csv
# AllDiode-ON-lr sweep.csv
# AllDiode-ON-lv sweep.csv
# AllDiode-ON-offset1 sweep.csv
# AllDiode-ON-pr sweep.csv
# AllDiode-ON-pr2 sweep.csv
# AllDiode-ON-w sweep.csv
# AllDiode-ON-wr sweep.csv
# AllDiode-ON-wu sweep.csv
# lowerDiode-ON-Alpha sweep.csv
# lowerDiode-ON-fx sweep.csv
# lowerDiode-ON-fy sweep.csv
# lowerDiode-ON-l sweep.csv
# lowerDiode-ON-lextention sweep.csv
# lowerDiode-ON-lh sweep.csv
# lowerDiode-ON-lr sweep.csv
# lowerDiode-ON-lv sweep.csv
# lowerDiode-ON-offset1 sweep.csv
# lowerDiode-ON-pr sweep.csv
# lowerDiode-ON-pr2 sweep.csv
# lowerDiode-ON-w sweep.csv
# lowerDiode-ON-wr sweep.csv
# lowerDiode-ON-wu sweep.csv
# upperDiode-ON-Alpha sweep.csv
# upperDiode-ON-fx sweep.csv
# upperDiode-ON-fy sweep.csv
# upperDiode-ON-l sweep.csv
# upperDiode-ON-lextention sweep.csv
# upperDiode-ON-lh sweep.csv
# upperDiode-ON-lr sweep.csv
# upperDiode-ON-lv sweep.csv
# upperDiode-ON-offset1 sweep.csv
# upperDiode-ON-pr sweep.csv
# upperDiode-ON-pr2 sweep.csv
# upperDiode-ON-w sweep.csv
# upperDiode-ON-wr sweep.csv
# upperDiode-ON-wu sweep.csv
# {0: 'AllDiode-OFF-Alpha sweep.csv', 1: 'AllDiode-OFF-fx sweep.csv', 2: 'AllDiode-OFF-fy sweep.csv', 3: 'AllDiode-OFF-l sweep.csv', 4: 'AllDiode-OFF-lextention sweep.csv', 5: 'AllDiode-OFF-lh sweep.csv', 6: 'AllDiode-OFF-lr sweep.csv', 7: 'AllDiode-OFF-lv sweep.csv', 8: 'AllDiode-OFF-offset1 sweep.csv', 9: 'AllDiode-OFF-pr sweep.csv', 10: 'AllDiode-OFF-pr2 sweep.csv', 11: 'AllDiode-OFF-w sweep.csv', 12: 'AllDiode-OFF-wr sweep.csv', 13: 'AllDiode-OFF-wu sweep.csv', 14: 'AllDiode-ON-Alpha sweep.csv', 15: 'AllDiode-ON-fx sweep.csv', 16: 'AllDiode-ON-fy sweep.csv', 17: 'AllDiode-ON-l sweep.csv', 18: 'AllDiode-ON-lextention sweep.csv', 19: 'AllDiode-ON-lh sweep.csv', 20: 'AllDiode-ON-lr sweep.csv', 21: 'AllDiode-ON-lv sweep.csv', 22: 'AllDiode-ON-offset1 sweep.csv', 23: 'AllDiode-ON-pr sweep.csv', 24: 'AllDiode-ON-pr2 sweep.csv', 25: 'AllDiode-ON-w sweep.csv', 26: 'AllDiode-ON-wr sweep.csv', 27: 'AllDiode-ON-wu sweep.csv', 28: 'lowerDiode-ON-Alpha sweep.csv', 29: 'lowerDiode-ON-fx sweep.csv', 30: 'lowerDiode-ON-fy sweep.csv', 31: 'lowerDiode-ON-l sweep.csv', 32: 'lowerDiode-ON-lextention sweep.csv', 33: 'lowerDiode-ON-lh sweep.csv', 34: 'lowerDiode-ON-lr sweep.csv', 35: 'lowerDiode-ON-lv sweep.csv', 36: 'lowerDiode-ON-offset1 sweep.csv', 37: 'lowerDiode-ON-pr sweep.csv', 38: 'lowerDiode-ON-pr2 sweep.csv', 39: 'lowerDiode-ON-w sweep.csv', 40: 'lowerDiode-ON-wr sweep.csv', 41: 'lowerDiode-ON-wu sweep.csv', 42: 'upperDiode-ON-Alpha sweep.csv', 43: 'upperDiode-ON-fx sweep.csv', 44: 'upperDiode-ON-fy sweep.csv', 45: 'upperDiode-ON-l sweep.csv', 46: 'upperDiode-ON-lextention sweep.csv', 47: 'upperDiode-ON-lh sweep.csv', 48: 'upperDiode-ON-lr sweep.csv', 49: 'upperDiode-ON-lv sweep.csv', 50: 'upperDiode-ON-offset1 sweep.csv', 51: 'upperDiode-ON-pr sweep.csv', 52: 'upperDiode-ON-pr2 sweep.csv', 53: 'upperDiode-ON-w sweep.csv', 54: 'upperDiode-ON-wr sweep.csv', 55: 'upperDiode-ON-wu sweep.csv'}

# %%
num_dfs = 14
n = 2
df = pd.DataFrame()
for i in range(num_dfs*(n-1), n*num_dfs):
    # Creating a sample DataFrame with random data
    df_new = pd.read_csv("C:/Backup - Oct 2024/Oct-2023 Backup/Users/msalmaniaran/PhD/Results-data/Reconfigurable-patch - Copy/"+str(dict_files[i])) 
    df = pd.concat([df, df_new], ignore_index=True)

# for i in range(4*num_dfs):
#     # Creating a sample DataFrame with random data
#     df_new = pd.read_csv("D:/Oct-2023 Backup/Users/msalmaniaran/PhD/Results-data/Reconfigurable-patch/"+str(dict_files[i])) 
#     df = pd.concat([df, df_new], ignore_index=True)

# %%
# print(df)
a =len(df)
b= a/250
print(int(b))
# Out:
# 641

# %%
# files = {}
# # num_dfs = len(files)
# num_dfs = 56

# for i in range(num_dfs):
#     # Creating a sample DataFrame with random data
#     df = pd.read_csv("D:/Oct-2023 Backup/Users/msalmaniaran/PhD/Results-data/Reconfigurable-patch/"+str(dict_files[i])) 
#     files[f'file{i}'] = df
#     # Identify NaN values using np.isnan
#     nan_indices = np.isnan(df)
#     #print(nan_indices)
#     # Use boolean indexing to drop NaN values
#     data_no_nan = df[~nan_indices.any(axis=1)]

# # Accessing the DataFrames
# for key, dataframe in files.items():
#     # Identify NaN values using np.isnan
#     nan_indices = np.isnan(dataframe)
#     #print(nan_indices)
#     # Use boolean indexing to drop NaN values
#     data_no_nan = dataframe[~nan_indices.any(axis=1)]
    
#     print(f'{key}:\n{dataframe}\n')

# %%
# def find_changes_in_column(df, column_name):
#     # Ensure the column exists in the DataFrame
#     if column_name not in df.columns:
#         return f"Column '{column_name}' does not exist in the DataFrame."
    
#     # Compare each value with the previous one in the column
#     change_locs = df[column_name].ne(df[column_name].shift())
#     change_indices = change_locs[change_locs].index.tolist()
    
#     return change_indices

# # Specify the column to search for changes
# column_to_search = 'alpha [mm]'

# # Find changes in the specified column
# changes_in_column = find_changes_in_column(files['file0'], column_to_search)
# print(f"Changes in column '{column_to_search}': {changes_in_column}")

# %%
# i = 0
# a = changes_in_column[i]
# b = changes_in_column[i+1]
# selected_rows = files['file0'][a:b]  # Note: the end index is exclusive
# print(selected_rows)

# %% [markdown]
# # Frequency Window

# %%
df_ys = df.drop(['alpha [mm]','fx [mm]', 'fy [mm]', 'l [mm]', 'lextension1 [mm]', 'lh [mm]', 'lr [mm]', 'lv [mm]', 'offset1 [mm]', 'pr [mm]', 'pr2 [mm]', 'w [mm]', 'wr [mm]', 'wu [mm]', 'Diode 1 state', 'Diode 2 state', 'Freq [GHz]'],axis=1)
ys_data = df_ys.values
df_yf = df.drop(['alpha [mm]','fx [mm]', 'fy [mm]', 'l [mm]', 'lextension1 [mm]', 'lh [mm]', 'lr [mm]', 'lv [mm]', 'offset1 [mm]', 'pr [mm]', 'pr2 [mm]', 'w [mm]', 'wr [mm]', 'wu [mm]', 'Diode 1 state', 'Diode 2 state', 'dB(S(1,1)) []'],axis=1)
yf_data = df_yf.values
df_y = df.drop(['alpha [mm]','fx [mm]', 'fy [mm]', 'l [mm]', 'lextension1 [mm]', 'lh [mm]', 'lr [mm]', 'lv [mm]', 'offset1 [mm]', 'pr [mm]', 'pr2 [mm]', 'w [mm]', 'wr [mm]', 'wu [mm]', 'Diode 1 state', 'Diode 2 state'],axis=1)
array = df_ys.values

a = len(df)
b = int(a/250)
reshaped_array = array.reshape(b, 250)   #250 is the number of sample points within 1-4 GHz.
df_yst = pd.DataFrame(reshaped_array)


# crob the frequency as needed
df_yst = df_yst.iloc[:, 40:-80] 
freq = df_yf.iloc[40:170].values
freq = np.squeeze(freq).tolist()


df_yst = df_yst.reset_index(drop=True)
# # Identify NaN values using np.isnan
# nan_indices = np.isnan(df_yst)
# #print(nan_indices)
# # Use boolean indexing to drop NaN values
# data_no_nan = df_yst[~nan_indices.any(axis=1)]

y_data = df_yst.values
print(df_yst)
# Out:
#           40        41        42        43        44        45        46   \
# 0   -0.166907 -0.167237 -0.167815 -0.168641 -0.169715 -0.171043 -0.172629
# 1   -0.165122 -0.165677 -0.166471 -0.167507 -0.168786 -0.170314 -0.172099
# 2   -0.163780 -0.164539 -0.165536 -0.166773 -0.168254 -0.169988 -0.171982
# 3   -0.164976 -0.165891 -0.167056 -0.168476 -0.170157 -0.172110 -0.174345
# 4   -0.150810 -0.149074 -0.147252 -0.145298 -0.143154 -0.140747 -0.137981
# ..        ...       ...       ...       ...       ...       ...       ...
# 636 -0.322439 -0.400779 -0.555587 -0.735884 -0.660780 -0.515567 -0.444127
# 637 -0.271383 -0.282738 -0.296043 -0.311318 -0.328688 -0.348366 -0.370641
# 638 -0.255434 -0.271437 -0.291639 -0.318551 -0.357145 -0.418085 -0.525488
# 639 -0.252223 -0.263932 -0.277015 -0.291739 -0.308465 -0.327700 -0.350180
# 640 -0.249725 -0.261555 -0.275034 -0.290542 -0.308622 -0.330077 -0.356141
#
#           47        48        49   ...       160       161       162  \
# 0   -0.174480 -0.176608 -0.179026  ... -0.967299 -1.025137 -1.103507
# 1   -0.174149 -0.176479 -0.179104  ... -0.967242 -1.033476 -1.122495
# 2   -0.174248 -0.176801 -0.179661  ... -1.030579 -1.122548 -1.246095
# 3   -0.176880 -0.179734 -0.182936  ... -1.534702 -1.810074 -2.200986
# 4   -0.134730 -0.130821 -0.126018  ... -1.562324 -1.857012 -2.275157
# ..        ...       ...       ...  ...       ...       ...       ...
# 636 -0.417720 -0.413162 -0.420407  ... -0.492119 -0.530200 -0.580445
# 637 -0.395888 -0.424583 -0.457327  ... -1.879039 -2.596949 -3.768207
# 638 -0.727565 -1.024401 -1.082427  ... -0.436005 -0.456449 -0.482708
# 639 -0.377028 -0.410034 -0.452218  ... -0.620836 -0.684498 -0.766770
# 640 -0.388812 -0.431495 -0.490347  ... -0.861243 -1.007200 -1.208485
#
#           163       164        165       166        167        168        169
# 0   -1.209113 -1.351694  -1.545705 -1.813065  -2.187791  -2.723885  -3.508816
# 1   -1.242044 -1.403460  -1.623693 -1.928656  -2.358846  -2.978876  -3.893408
# 2   -1.412978 -1.640801  -1.956530 -2.402433  -3.046167  -3.997726  -5.435918
# 3   -2.768362 -3.612661  -4.901457 -6.908759  -9.988565 -13.413556 -12.229159
# 4   -2.881904 -3.783890  -5.155787 -7.268078 -10.368883 -13.086294 -11.273524
# ..        ...       ...        ...       ...        ...        ...        ...
# 636 -0.647250 -0.737197  -0.860410 -1.032944  -1.281114  -1.649598  -2.216857
# 637 -5.725758 -8.860029 -11.732149 -9.646979  -6.570356  -4.577156  -3.354612
# 638 -0.516260 -0.559173  -0.614387 -0.686179  -0.780920  -0.908348  -1.083805
# 639 -0.874429 -1.017533  -1.211388 -1.479938  -1.861733  -2.420733  -3.266297
# 640 -1.492930 -1.906315  -2.525941 -3.484739  -5.010207  -7.456970 -10.980542
#
# [641 rows x 130 columns]

# %%
df_x = df.drop(['Freq [GHz]', 'dB(S(1,1)) []', 'Diode 2 state', 'Diode 1 state' ,'alpha [mm]'], axis=1)
df_x_selected = df_x.iloc[::250].reset_index(drop=True)

df_concat = pd.concat([df_x_selected, df_yst], axis=1)
# # Identify NaN values using np.isnan
# nan_indices = np.isnan(df_selected)
# # print(nan_indices)
# # Use boolean indexing to drop NaN values
# data_no_nan = df_selected[~nan_indices.any(axis=1)]

df_filtered = df_concat.dropna()


print(df_x_selected.head())
# Out:
#    fx [mm]  fy [mm]   l [mm]  lextension1 [mm]  lh [mm]  lr [mm]  lv [mm]  \
# 0  18.3360   7.4080  47.6640           21.2000  41.5360  2.20000  21.0880
# 1  18.4506   7.4543  47.9619           21.3325  41.7956  2.21375  21.2198
# 2  18.5652   7.5006  48.2598           21.4650  42.0552  2.22750  21.3516
# 3  18.6798   7.5469  48.5577           21.5975  42.3148  2.24125  21.4834
# 4  18.7944   7.5932  48.8556           21.7300  42.5744  2.25500  21.6152
#
#    offset1 [mm]  pr [mm]  pr2 [mm]  w [mm]  wr [mm]  wu [mm]
# 0         28.80    997.2   19.8720  56.160  4.95200   4.7040
# 1         28.98   1247.2   19.9962  56.511  4.98295   4.7334
# 2         29.16   1497.2   20.1204  56.862  5.01390   4.7628
# 3         29.34   1747.2   20.2446  57.213  5.04485   4.7922
# 4         29.52   1997.2   20.3688  57.564  5.07580   4.8216

# %%
# Define the threshold
threshold = 0

# Specify the column range to check
start_col = int(df_yst.columns[0])
end_col = len(df_yst.columns)-1

# Select the column names based on the range
columns_to_check = [i for i in range(start_col, end_col + 1)]

# Drop rows where any value in specified columns exceeds the threshold
df_all = df_filtered[df_filtered[columns_to_check].le(threshold).all(axis=1)]

df_all = df_all.reset_index(drop=True)
print(df_all)
# Out:
#      fx [mm]  fy [mm]   l [mm]  lextension1 [mm]  lh [mm]  lr [mm]  lv [mm]  \
# 0    18.3360   7.4080  47.6640           21.2000  41.5360  2.20000  21.0880
# 1    18.4506   7.4543  47.9619           21.3325  41.7956  2.21375  21.2198
# 2    18.5652   7.5006  48.2598           21.4650  42.0552  2.22750  21.3516
# 3    18.6798   7.5469  48.5577           21.5975  42.3148  2.24125  21.4834
# 4    18.9090   7.6395  49.1535           21.8625  42.8340  2.26875  21.7470
# ..       ...      ...      ...               ...      ...      ...      ...
# 633  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 634  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 635  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 636  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 637  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
#
#      offset1 [mm]  pr [mm]  pr2 [mm]  ...       160       161       162  \
# 0           28.80    997.2   19.8720  ... -0.967299 -1.025137 -1.103507
# 1           28.98   1247.2   19.9962  ... -0.967242 -1.033476 -1.122495
# 2           29.16   1497.2   20.1204  ... -1.030579 -1.122548 -1.246095
# 3           29.34   1747.2   20.2446  ... -1.534702 -1.810074 -2.200986
# 4           29.70   2247.2   20.4930  ... -2.062764 -2.589106 -3.370646
# ..            ...      ...       ...  ...       ...       ...       ...
# 633         35.38     -2.8   24.4100  ... -0.492119 -0.530200 -0.580445
# 634         35.38     -2.8   24.4100  ... -1.879039 -2.596949 -3.768207
# 635         35.38     -2.8   24.4100  ... -0.436005 -0.456449 -0.482708
# 636         35.38     -2.8   24.4100  ... -0.620836 -0.684498 -0.766770
# 637         35.38     -2.8   24.4100  ... -0.861243 -1.007200 -1.208485
#
#           163       164        165        166        167        168        169
# 0   -1.209113 -1.351694  -1.545705  -1.813065  -2.187791  -2.723885  -3.508816
# 1   -1.242044 -1.403460  -1.623693  -1.928656  -2.358846  -2.978876  -3.893408
# 2   -1.412978 -1.640801  -1.956530  -2.402433  -3.046167  -3.997726  -5.435918
# 3   -2.768362 -3.612661  -4.901457  -6.908759  -9.988565 -13.413556 -12.229159
# 4   -4.559746 -6.400561  -9.195353 -12.412350 -11.945406  -8.737509  -6.236628
# ..        ...       ...        ...        ...        ...        ...        ...
# 633 -0.647250 -0.737197  -0.860410  -1.032944  -1.281114  -1.649598  -2.216857
# 634 -5.725758 -8.860029 -11.732149  -9.646979  -6.570356  -4.577156  -3.354612
# 635 -0.516260 -0.559173  -0.614387  -0.686179  -0.780920  -0.908348  -1.083805
# 636 -0.874429 -1.017533  -1.211388  -1.479938  -1.861733  -2.420733  -3.266297
# 637 -1.492930 -1.906315  -2.525941  -3.484739  -5.010207  -7.456970 -10.980542
#
# [638 rows x 143 columns]

# %%
# df_all2 = df_all

# %%
# df_all2.iloc[153,:]

# %%
# # # Drop the row with index 2
# df_all = df_all.drop(153)

# # # Reset the index if needed (optional)
# df_all = df_all.reset_index(drop=True)

# %%
# # # Drop the row with index 2
# df_all = df_all.drop(369)

# # # Reset the index if needed (optional)
# df_all = df_all.reset_index(drop=True)

# %%
threshold = -10
df_all = df_all.loc[~(df_all[df_all.columns[16:]] > threshold).all(axis=1)]
df_all = df_all.reset_index(drop=True)

# %%
df_all
# Out:
#      fx [mm]  fy [mm]   l [mm]  lextension1 [mm]  lh [mm]  lr [mm]  lv [mm]  \
# 0    18.3360   7.4080  47.6640           21.2000  41.5360  2.20000  21.0880
# 1    18.4506   7.4543  47.9619           21.3325  41.7956  2.21375  21.2198
# 2    18.5652   7.5006  48.2598           21.4650  42.0552  2.22750  21.3516
# 3    18.6798   7.5469  48.5577           21.5975  42.3148  2.24125  21.4834
# 4    18.9090   7.6395  49.1535           21.8625  42.8340  2.26875  21.7470
# ..       ...      ...      ...               ...      ...      ...      ...
# 583  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 584  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 585  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 586  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 587  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
#
#      offset1 [mm]  pr [mm]  pr2 [mm]  ...       160       161       162  \
# 0           28.80    997.2   19.8720  ... -0.967299 -1.025137 -1.103507
# 1           28.98   1247.2   19.9962  ... -0.967242 -1.033476 -1.122495
# 2           29.16   1497.2   20.1204  ... -1.030579 -1.122548 -1.246095
# 3           29.34   1747.2   20.2446  ... -1.534702 -1.810074 -2.200986
# 4           29.70   2247.2   20.4930  ... -2.062764 -2.589106 -3.370646
# ..            ...      ...       ...  ...       ...       ...       ...
# 583         35.38     -2.8   24.4100  ... -0.492119 -0.530200 -0.580445
# 584         35.38     -2.8   24.4100  ... -1.879039 -2.596949 -3.768207
# 585         35.38     -2.8   24.4100  ... -0.436005 -0.456449 -0.482708
# 586         35.38     -2.8   24.4100  ... -0.620836 -0.684498 -0.766770
# 587         35.38     -2.8   24.4100  ... -0.861243 -1.007200 -1.208485
#
#           163       164        165        166        167        168        169
# 0   -1.209113 -1.351694  -1.545705  -1.813065  -2.187791  -2.723885  -3.508816
# 1   -1.242044 -1.403460  -1.623693  -1.928656  -2.358846  -2.978876  -3.893408
# 2   -1.412978 -1.640801  -1.956530  -2.402433  -3.046167  -3.997726  -5.435918
# 3   -2.768362 -3.612661  -4.901457  -6.908759  -9.988565 -13.413556 -12.229159
# 4   -4.559746 -6.400561  -9.195353 -12.412350 -11.945406  -8.737509  -6.236628
# ..        ...       ...        ...        ...        ...        ...        ...
# 583 -0.647250 -0.737197  -0.860410  -1.032944  -1.281114  -1.649598  -2.216857
# 584 -5.725758 -8.860029 -11.732149  -9.646979  -6.570356  -4.577156  -3.354612
# 585 -0.516260 -0.559173  -0.614387  -0.686179  -0.780920  -0.908348  -1.083805
# 586 -0.874429 -1.017533  -1.211388  -1.479938  -1.861733  -2.420733  -3.266297
# 587 -1.492930 -1.906315  -2.525941  -3.484739  -5.010207  -7.456970 -10.980542
#
# [588 rows x 143 columns]

# %% [markdown]
# # Post-Processing (if needed for removing out range data)

# %%
df_all.reset_index(drop=True, inplace=True)
df_all.drop(index_lowR2, inplace=True)
df_all.reset_index(drop=True, inplace=True)

# %%
df_all
# Out:
#      fx [mm]  fy [mm]   l [mm]  lextension1 [mm]  lh [mm]  lr [mm]  lv [mm]  \
# 0    18.3360   7.4080  47.6640           21.2000  41.5360  2.20000  21.0880
# 1    18.4506   7.4543  47.9619           21.3325  41.7956  2.21375  21.2198
# 2    18.5652   7.5006  48.2598           21.4650  42.0552  2.22750  21.3516
# 3    18.6798   7.5469  48.5577           21.5975  42.3148  2.24125  21.4834
# 4    18.9090   7.6395  49.1535           21.8625  42.8340  2.26875  21.7470
# ..       ...      ...      ...               ...      ...      ...      ...
# 558  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 559  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 560  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 561  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 562  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
#
#      offset1 [mm]  pr [mm]  pr2 [mm]  ...       160       161       162  \
# 0           28.80    997.2   19.8720  ... -0.967299 -1.025137 -1.103507
# 1           28.98   1247.2   19.9962  ... -0.967242 -1.033476 -1.122495
# 2           29.16   1497.2   20.1204  ... -1.030579 -1.122548 -1.246095
# 3           29.34   1747.2   20.2446  ... -1.534702 -1.810074 -2.200986
# 4           29.70   2247.2   20.4930  ... -2.062764 -2.589106 -3.370646
# ..            ...      ...       ...  ...       ...       ...       ...
# 558         35.38     -2.8   24.4100  ... -0.395518 -0.410806 -0.431045
# 559         35.38     -2.8   24.4100  ... -0.492119 -0.530200 -0.580445
# 560         35.38     -2.8   24.4100  ... -1.879039 -2.596949 -3.768207
# 561         35.38     -2.8   24.4100  ... -0.620836 -0.684498 -0.766770
# 562         35.38     -2.8   24.4100  ... -0.861243 -1.007200 -1.208485
#
#           163       164        165        166        167        168        169
# 0   -1.209113 -1.351694  -1.545705  -1.813065  -2.187791  -2.723885  -3.508816
# 1   -1.242044 -1.403460  -1.623693  -1.928656  -2.358846  -2.978876  -3.893408
# 2   -1.412978 -1.640801  -1.956530  -2.402433  -3.046167  -3.997726  -5.435918
# 3   -2.768362 -3.612661  -4.901457  -6.908759  -9.988565 -13.413556 -12.229159
# 4   -4.559746 -6.400561  -9.195353 -12.412350 -11.945406  -8.737509  -6.236628
# ..        ...       ...        ...        ...        ...        ...        ...
# 558 -0.457556 -0.492189  -0.537577  -0.597544  -0.677775  -0.786956  -0.938763
# 559 -0.647250 -0.737197  -0.860410  -1.032944  -1.281114  -1.649598  -2.216857
# 560 -5.725758 -8.860029 -11.732149  -9.646979  -6.570356  -4.577156  -3.354612
# 561 -0.874429 -1.017533  -1.211388  -1.479938  -1.861733  -2.420733  -3.266297
# 562 -1.492930 -1.906315  -2.525941  -3.484739  -5.010207  -7.456970 -10.980542
#
# [563 rows x 143 columns]

# %%
df_y = df_all.iloc[:, 13:]
# df_y = df_y.reset_index(drop=True)
y_data = df_y.values
print(df_y)
# Out:
#           40        41        42        43        44        45        46   \
# 0   -0.166907 -0.167237 -0.167815 -0.168641 -0.169715 -0.171043 -0.172629
# 1   -0.165122 -0.165677 -0.166471 -0.167507 -0.168786 -0.170314 -0.172099
# 2   -0.163780 -0.164539 -0.165536 -0.166773 -0.168254 -0.169988 -0.171982
# 3   -0.164976 -0.165891 -0.167056 -0.168476 -0.170157 -0.172110 -0.174345
# 4   -0.164643 -0.165967 -0.167551 -0.169404 -0.171536 -0.173961 -0.176697
# ..        ...       ...       ...       ...       ...       ...       ...
# 558 -0.269109 -0.292891 -0.327897 -0.385709 -0.493737 -0.696295 -0.881455
# 559 -0.322439 -0.400779 -0.555587 -0.735884 -0.660780 -0.515567 -0.444127
# 560 -0.271383 -0.282738 -0.296043 -0.311318 -0.328688 -0.348366 -0.370641
# 561 -0.252223 -0.263932 -0.277015 -0.291739 -0.308465 -0.327700 -0.350180
# 562 -0.249725 -0.261555 -0.275034 -0.290542 -0.308622 -0.330077 -0.356141
#
#           47        48        49   ...       160       161       162  \
# 0   -0.174480 -0.176608 -0.179026  ... -0.967299 -1.025137 -1.103507
# 1   -0.174149 -0.176479 -0.179104  ... -0.967242 -1.033476 -1.122495
# 2   -0.174248 -0.176801 -0.179661  ... -1.030579 -1.122548 -1.246095
# 3   -0.176880 -0.179734 -0.182936  ... -1.534702 -1.810074 -2.200986
# 4   -0.179768 -0.183204 -0.187046  ... -2.062764 -2.589106 -3.370646
# ..        ...       ...       ...  ...       ...       ...       ...
# 558 -0.763170 -0.603237 -0.526360  ... -0.395518 -0.410806 -0.431045
# 559 -0.417720 -0.413162 -0.420407  ... -0.492119 -0.530200 -0.580445
# 560 -0.395888 -0.424583 -0.457327  ... -1.879039 -2.596949 -3.768207
# 561 -0.377028 -0.410034 -0.452218  ... -0.620836 -0.684498 -0.766770
# 562 -0.388812 -0.431495 -0.490347  ... -0.861243 -1.007200 -1.208485
#
#           163       164        165        166        167        168        169
# 0   -1.209113 -1.351694  -1.545705  -1.813065  -2.187791  -2.723885  -3.508816
# 1   -1.242044 -1.403460  -1.623693  -1.928656  -2.358846  -2.978876  -3.893408
# 2   -1.412978 -1.640801  -1.956530  -2.402433  -3.046167  -3.997726  -5.435918
# 3   -2.768362 -3.612661  -4.901457  -6.908759  -9.988565 -13.413556 -12.229159
# 4   -4.559746 -6.400561  -9.195353 -12.412350 -11.945406  -8.737509  -6.236628
# ..        ...       ...        ...        ...        ...        ...        ...
# 558 -0.457556 -0.492189  -0.537577  -0.597544  -0.677775  -0.786956  -0.938763
# 559 -0.647250 -0.737197  -0.860410  -1.032944  -1.281114  -1.649598  -2.216857
# 560 -5.725758 -8.860029 -11.732149  -9.646979  -6.570356  -4.577156  -3.354612
# 561 -0.874429 -1.017533  -1.211388  -1.479938  -1.861733  -2.420733  -3.266297
# 562 -1.492930 -1.906315  -2.525941  -3.484739  -5.010207  -7.456970 -10.980542
#
# [563 rows x 130 columns]

# %%
# df_x = df_all.iloc[:, :16]
df_x = df_all.iloc[:, :13]
x_data = df_x.values
print(df_x)
# Out:
#      fx [mm]  fy [mm]   l [mm]  lextension1 [mm]  lh [mm]  lr [mm]  lv [mm]  \
# 0    18.3360   7.4080  47.6640           21.2000  41.5360  2.20000  21.0880
# 1    18.4506   7.4543  47.9619           21.3325  41.7956  2.21375  21.2198
# 2    18.5652   7.5006  48.2598           21.4650  42.0552  2.22750  21.3516
# 3    18.6798   7.5469  48.5577           21.5975  42.3148  2.24125  21.4834
# 4    18.9090   7.6395  49.1535           21.8625  42.8340  2.26875  21.7470
# ..       ...      ...      ...               ...      ...      ...      ...
# 558  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 559  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 560  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 561  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
# 562  22.5300   9.1000  58.5600           26.0400  51.0300  2.70000  25.9100
#
#      offset1 [mm]  pr [mm]  pr2 [mm]  w [mm]  wr [mm]    wu [mm]
# 0           28.80    997.2   19.8720  56.160  4.95200   4.704000
# 1           28.98   1247.2   19.9962  56.511  4.98295   4.733400
# 2           29.16   1497.2   20.1204  56.862  5.01390   4.762800
# 3           29.34   1747.2   20.2446  57.213  5.04485   4.792200
# 4           29.70   2247.2   20.4930  57.915  5.10675   4.851000
# ..            ...      ...       ...     ...      ...        ...
# 558         35.38     -2.8   24.4100  69.000  6.08000   8.846154
# 559         35.38     -2.8   24.4100  69.000  6.08000   9.076923
# 560         35.38     -2.8   24.4100  69.000  6.08000   9.307692
# 561         35.38     -2.8   24.4100  69.000  6.08000   9.769231
# 562         35.38     -2.8   24.4100  69.000  6.08000  10.000000
#
# [563 rows x 13 columns]

# %%
# # PCA
# from sklearn.preprocessing import StandardScaler
# scalar = StandardScaler()
# x_standard = scalar.fit_transform(x_data)
# from sklearn.decomposition import PCA
# n_pca = 12
# pca = PCA(n_components=n_pca)

# principalComponents = pca.fit_transform(x_standard)
# principalDf = pd.DataFrame(data = principalComponents
#              , columns = [f'principal component {i}' for i in range(n_pca)])

# # principalDf
# principalDf_values = principalDf.values 
# original = pca.inverse_transform(principalDf_values)
# originalDF = pd.DataFrame(data = original
#              , columns = [f'principal component {i}' for i in range(16)])

# # originalDF
# original_2 = scalar.inverse_transform(original)
# originalDF_2 = pd.DataFrame(data = original_2
#              , columns = [f'principal component {i}' for i in range(16)])

# # originalDF_2

# %%
# y_data[153]

# %%
print(np.any(np.isnan(x_data)), np.any(np.isinf(x_data)))
print(np.any(np.isnan(ys_data)), np.any(np.isinf(ys_data)))
# Out:
# False False
# False False

# %%
# freq = np.squeeze(yf_data[:len(df_yst.columns)]).tolist()
# freq = freq[40:-40]
print(freq)
# Out:
# [1.481927711, 1.493975904, 1.506024096, 1.518072289, 1.530120482, 1.542168675, 1.554216867, 1.56626506, 1.578313253, 1.590361446, 1.602409639, 1.614457831, 1.626506024, 1.638554217, 1.65060241, 1.662650602, 1.674698795, 1.686746988, 1.698795181, 1.710843373, 1.722891566, 1.734939759, 1.746987952, 1.759036145, 1.771084337, 1.78313253, 1.795180723, 1.807228916, 1.819277108, 1.831325301, 1.843373494, 1.855421687, 1.86746988, 1.879518072, 1.891566265, 1.903614458, 1.915662651, 1.927710843, 1.939759036, 1.951807229, 1.963855422, 1.975903614, 1.987951807, 2.0, 2.012048193, 2.024096386, 2.036144578, 2.048192771, 2.060240964, 2.072289157, 2.084337349, 2.096385542, 2.108433735, 2.120481928, 2.13253012, 2.144578313, 2.156626506, 2.168674699, 2.180722892, 2.192771084, 2.204819277, 2.21686747, 2.228915663, 2.240963855, 2.253012048, 2.265060241, 2.277108434, 2.289156627, 2.301204819, 2.313253012, 2.325301205, 2.337349398, 2.34939759, 2.361445783, 2.373493976, 2.385542169, 2.397590361, 2.409638554, 2.421686747, 2.43373494, 2.445783133, 2.457831325, 2.469879518, 2.481927711, 2.493975904, 2.506024096, 2.518072289, 2.530120482, 2.542168675, 2.554216867, 2.56626506, 2.578313253, 2.590361446, 2.602409639, 2.614457831, 2.626506024, 2.638554217, 2.65060241, 2.662650602, 2.674698795, 2.686746988, 2.698795181, 2.710843373, 2.722891566, 2.734939759, 2.746987952, 2.759036145, 2.771084337, 2.78313253, 2.795180723, 2.807228916, 2.819277108, 2.831325301, 2.843373494, 2.855421687, 2.86746988, 2.879518072, 2.891566265, 2.903614458, 2.915662651, 2.927710843, 2.939759036, 2.951807229, 2.963855422, 2.975903614, 2.987951807, 3.0, 3.012048193, 3.024096386, 3.036144578]

# %% [markdown]
# # Autoencoder with attention layers

# %%
# dim = y_data.shape[1]
# input_dimension = len(ys_data[0:dim])
# units =512
# activation = 'relu'
# momentum = 0.95
# learning_rate = 0.1
# loss = 'mean_squared_error'
# output_dimension = len(ys_data[0:dim])
# import tensorflow as tf
# from tensorflow.keras.layers import Input, Dense, Attention, Concatenate
# from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import SGD

# def create_model2(units, activation, dim, learning_rate, momentum, loss):
#     # Define the input
#     input_layer = Input(shape=(dim,), name='input')

#     # Encoder
#     encoder = Dense(units, activation=activation, name='encoder_0')(input_layer)
#     encoder = Dense(units // 2, activation=activation, name='encoder_1')(encoder)
#     encoder = Dense(units // 4, activation=activation, name='encoder_2')(encoder)
#     encoder = Dense(units // 8, activation=activation, name='encoder_3')(encoder)
    
#     # Attention layer in the encoder
#     query_enc = Dense(units // 32, activation='relu', name='query_enc')(encoder)
#     key_enc = Dense(units // 32, activation='relu', name='key_enc')(encoder)
#     value_enc = Dense(units // 32, activation='relu', name='value_enc')(encoder)
#     attention_enc = Attention(name='attention_enc')([query_enc, value_enc, key_enc])
#     encoder_output = Concatenate(name='encoder_output')([encoder, attention_enc])

    
#     # Decoder
#     decoder = Dense(units // 16, activation=activation, name='decoder_0')(encoder_output)
#     decoder = Dense(units // 8, activation=activation, name='decoder_1')(decoder)
#     decoder = Dense(units // 4, activation=activation, name='decoder_2')(decoder)
#     decoder = Dense(units // 2, activation=activation, name='decoder_3')(decoder)
#     decoder = Dense(units, activation=activation, name='decoder_4')(decoder)

#     # Attention layer in the decoder
#     query_dec = Dense(units // 32, activation='relu', name='query_dec')(decoder)
#     key_dec = Dense(units // 32, activation='relu', name='key_dec')(decoder)
#     value_dec = Dense(units // 32, activation='relu', name='value_dec')(decoder)
#     attention_dec = Attention(name='attention_dec')([query_dec, value_dec, key_dec])
#     decoder_output = Concatenate(name='decoder_output')([decoder, attention_dec])

    
#     # Output layer
#     output_layer = Dense(dim, name='output')(decoder_output)

#     # Define the model
#     model = Model(inputs=input_layer, outputs=output_layer, name='autoencoder')

#     # Compile the model
#     optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
#     model.compile(optimizer=optimizer, loss=loss)

#     return model
# # Create the model
# autoencoder = create_model2(units, activation, dim, learning_rate, momentum, loss)

# # Print the model summary
# autoencoder.summary()

# %% [markdown]
# # Autoencoder

# %%
dim = y_data.shape[1]
input_dimension = len(ys_data[0:dim])
units =512
activation = 'tanh'
momentum = 0.95
learning_rate = 0.01
loss = 'mean_squared_error'
output_dimension = len(ys_data[0:dim])
def create_model2(units=units, activation=activation):

    model = Sequential()

    model.add(Dense(units, input_dim=dim, activation=activation, name = '0'))  # Adjust input_dim to match number of features
    model.add(Dense(int(units/2), activation=activation, name = '1'))
    model.add(Dense(int(units/4), activation=activation, name = '2'))
    model.add(Dense(int(units/8), activation=activation, name = '3'))
    model.add(Dense(int(units/16), activation=activation, name = '4'))
    model.add(Dense(int(units/8), activation=activation, name = '5'))
    model.add(Dense(int(units/4), activation=activation, name = '6'))
    model.add(Dense(int(units/2), activation=activation, name = '7'))
    model.add(Dense(units, activation=activation, name = '8'))
    model.add(Dense(dim, name = '9'))  # Output layer should match the number of features
    optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=optimizer, loss=loss)
    return model

autoencoder = create_model2()
autoencoder.summary()
# Out:
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ 0 (Dense)                            │ (None, 512)                 │          67,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 1 (Dense)                            │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 2 (Dense)                            │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 3 (Dense)                            │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 4 (Dense)                            │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 5 (Dense)                            │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 6 (Dense)                            │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 7 (Dense)                            │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 8 (Dense)                            │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 9 (Dense)                            │ (None, 130)                 │          66,690 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 483,362 (1.84 MB)
#  Trainable params: 483,362 (1.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_train, y_test = train_test_split(y_data, test_size=0.15, random_state=10)
# print(y_train[0])

scaler_y = StandardScaler()
scaler_y.fit(y_train)
y_train = scaler_y.transform(y_train)
y_test = scaler_y.transform(y_test)
y_data_scaled = scaler_y.transform(y_data)

# %%
from joblib import dump, load
dump(scaler_y, 'scaler_y2.bin', compress=True)
# Out:
# ['scaler_y2.bin']

# %%
epoch = 512
batch_sizes = 16
history = autoencoder.fit(y_train, y_train, epochs=epoch, batch_size=batch_sizes, validation_data=(y_test, y_test))

# Extract the training loss values
training_loss = history.history['loss']

# Extract the validation loss values (if available)
validation_loss = history.history['val_loss']

# Create an array of epoch numbers (or steps)
epochs = range(1, len(training_loss) + 1)

# Plot the training and validation loss vs. epochs
plt.plot(epochs, training_loss, label='Training Loss')
if validation_loss:
    plt.plot(epochs, validation_loss, label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.legend()
plt.show()

#loss = CenterFrequency.evaluate(x1_test,y1_test, verbose=1)
#print('Test set\n  Loss: {:0.3f}'.format(loss))
# Out:
# Epoch 1/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9763 - val_loss: 0.8032
# Epoch 2/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7599 - val_loss: 0.6673
# Epoch 3/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6217 - val_loss: 0.5718
# Epoch 4/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5233 - val_loss: 0.5017
# Epoch 5/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4565 - val_loss: 0.4504
# Epoch 6/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4064 - val_loss: 0.4112
# Epoch 7/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3694 - val_loss: 0.3787
# Epoch 8/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3413 - val_loss: 0.3552
# Epoch 9/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3166 - val_loss: 0.3357
# Epoch 10/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2963 - val_loss: 0.3189
# Epoch 11/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2795 - val_loss: 0.3095
# Epoch 12/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2653 - val_loss: 0.2954
# Epoch 13/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2548 - val_loss: 0.2862
# Epoch 14/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2454 - val_loss: 0.2827
# Epoch 15/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2389 - val_loss: 0.2765
# Epoch 16/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2303 - val_loss: 0.2670
# Epoch 17/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2248 - val_loss: 0.2577
# Epoch 18/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2161 - val_loss: 0.2496
# Epoch 19/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2077 - val_loss: 0.2428
# Epoch 20/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1994 - val_loss: 0.2370
# Epoch 21/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1926 - val_loss: 0.2286
# Epoch 22/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1842 - val_loss: 0.2259
# Epoch 23/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1788 - val_loss: 0.2192
# Epoch 24/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1721 - val_loss: 0.2134
# Epoch 25/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1672 - val_loss: 0.2096
# Epoch 26/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1628 - val_loss: 0.2072
# Epoch 27/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1599 - val_loss: 0.2050
# Epoch 28/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1576 - val_loss: 0.2033
# Epoch 29/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1550 - val_loss: 0.1985
# Epoch 30/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1521 - val_loss: 0.1959
# Epoch 31/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1491 - val_loss: 0.1916
# Epoch 32/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1471 - val_loss: 0.1914
# Epoch 33/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1448 - val_loss: 0.1869
# Epoch 34/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1431 - val_loss: 0.1864
# Epoch 35/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1402 - val_loss: 0.1831
# Epoch 36/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1385 - val_loss: 0.1803
# Epoch 37/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1369 - val_loss: 0.1793
# Epoch 38/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1348 - val_loss: 0.1761
# Epoch 39/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1323 - val_loss: 0.1748
# Epoch 40/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1305 - val_loss: 0.1707
# Epoch 41/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1290 - val_loss: 0.1697
# Epoch 42/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1267 - val_loss: 0.1672
# Epoch 43/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1248 - val_loss: 0.1672
# Epoch 44/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1236 - val_loss: 0.1663
# Epoch 45/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1220 - val_loss: 0.1661
# Epoch 46/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1213 - val_loss: 0.1649
# Epoch 47/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1194 - val_loss: 0.1629
# Epoch 48/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1188 - val_loss: 0.1613
# Epoch 49/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1166 - val_loss: 0.1604
# Epoch 50/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1160 - val_loss: 0.1591
# Epoch 51/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1142 - val_loss: 0.1575
# Epoch 52/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1138 - val_loss: 0.1558
# Epoch 53/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1119 - val_loss: 0.1546
# Epoch 54/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1108 - val_loss: 0.1518
# Epoch 55/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1095 - val_loss: 0.1523
# Epoch 56/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1084 - val_loss: 0.1491
# Epoch 57/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1073 - val_loss: 0.1502
# Epoch 58/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1059 - val_loss: 0.1473
# Epoch 59/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1044 - val_loss: 0.1484
# Epoch 60/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1030 - val_loss: 0.1458
# Epoch 61/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1017 - val_loss: 0.1467
# Epoch 62/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1004 - val_loss: 0.1442
# Epoch 63/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0991 - val_loss: 0.1442
# Epoch 64/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0976 - val_loss: 0.1423
# Epoch 65/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0963 - val_loss: 0.1418
# Epoch 66/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0951 - val_loss: 0.1404
# Epoch 67/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0938 - val_loss: 0.1396
# Epoch 68/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0927 - val_loss: 0.1388
# Epoch 69/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0915 - val_loss: 0.1380
# Epoch 70/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0904 - val_loss: 0.1374
# Epoch 71/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0893 - val_loss: 0.1368
# Epoch 72/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0882 - val_loss: 0.1358
# Epoch 73/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0872 - val_loss: 0.1355
# Epoch 74/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0863 - val_loss: 0.1341
# Epoch 75/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0853 - val_loss: 0.1341
# Epoch 76/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0844 - val_loss: 0.1327
# Epoch 77/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0835 - val_loss: 0.1328
# Epoch 78/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0826 - val_loss: 0.1314
# Epoch 79/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0816 - val_loss: 0.1312
# Epoch 80/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0808 - val_loss: 0.1303
# Epoch 81/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0799 - val_loss: 0.1296
# Epoch 82/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0790 - val_loss: 0.1293
# Epoch 83/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0781 - val_loss: 0.1283
# Epoch 84/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0772 - val_loss: 0.1280
# Epoch 85/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0763 - val_loss: 0.1270
# Epoch 86/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0755 - val_loss: 0.1269
# Epoch 87/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0746 - val_loss: 0.1260
# Epoch 88/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0739 - val_loss: 0.1260
# Epoch 89/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0731 - val_loss: 0.1250
# Epoch 90/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0724 - val_loss: 0.1248
# Epoch 91/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0717 - val_loss: 0.1236
# Epoch 92/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0711 - val_loss: 0.1240
# Epoch 93/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0704 - val_loss: 0.1233
# Epoch 94/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0700 - val_loss: 0.1237
# Epoch 95/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0696 - val_loss: 0.1227
# Epoch 96/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0689 - val_loss: 0.1221
# Epoch 97/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0683 - val_loss: 0.1212
# Epoch 98/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0683 - val_loss: 0.1212
# Epoch 99/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0677 - val_loss: 0.1199
# Epoch 100/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0666 - val_loss: 0.1206
# Epoch 101/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0663 - val_loss: 0.1199
# Epoch 102/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0660 - val_loss: 0.1180
# Epoch 103/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0645 - val_loss: 0.1174
# Epoch 104/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0640 - val_loss: 0.1179
# Epoch 105/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0636 - val_loss: 0.1170
# Epoch 106/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0628 - val_loss: 0.1181
# Epoch 107/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0625 - val_loss: 0.1156
# Epoch 108/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0620 - val_loss: 0.1155
# Epoch 109/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0608 - val_loss: 0.1147
# Epoch 110/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0607 - val_loss: 0.1157
# Epoch 111/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0603 - val_loss: 0.1133
# Epoch 112/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0594 - val_loss: 0.1139
# Epoch 113/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0588 - val_loss: 0.1124
# Epoch 114/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0585 - val_loss: 0.1140
# Epoch 115/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0581 - val_loss: 0.1119
# Epoch 116/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0575 - val_loss: 0.1126
# Epoch 117/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0572 - val_loss: 0.1114
# Epoch 118/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0569 - val_loss: 0.1120
# Epoch 119/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0568 - val_loss: 0.1110
# Epoch 120/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0562 - val_loss: 0.1112
# Epoch 121/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0559 - val_loss: 0.1092
# Epoch 122/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0547 - val_loss: 0.1100
# Epoch 123/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0542 - val_loss: 0.1078
# Epoch 124/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0530 - val_loss: 0.1085
# Epoch 125/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0524 - val_loss: 0.1067
# Epoch 126/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0516 - val_loss: 0.1074
# Epoch 127/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0514 - val_loss: 0.1062
# Epoch 128/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0507 - val_loss: 0.1068
# Epoch 129/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0505 - val_loss: 0.1057
# Epoch 130/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0499 - val_loss: 0.1057
# Epoch 131/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0496 - val_loss: 0.1053
# Epoch 132/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0488 - val_loss: 0.1051
# Epoch 133/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0485 - val_loss: 0.1046
# Epoch 134/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0476 - val_loss: 0.1042
# Epoch 135/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0473 - val_loss: 0.1039
# Epoch 136/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0465 - val_loss: 0.1037
# Epoch 137/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0462 - val_loss: 0.1029
# Epoch 138/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0457 - val_loss: 0.1035
# Epoch 139/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0454 - val_loss: 0.1021
# Epoch 140/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0450 - val_loss: 0.1033
# Epoch 141/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0448 - val_loss: 0.1014
# Epoch 142/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0445 - val_loss: 0.1029
# Epoch 143/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0445 - val_loss: 0.1010
# Epoch 144/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0441 - val_loss: 0.1024
# Epoch 145/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0439 - val_loss: 0.1005
# Epoch 146/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0434 - val_loss: 0.1017
# Epoch 147/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0430 - val_loss: 0.1002
# Epoch 148/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0425 - val_loss: 0.1009
# Epoch 149/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0420 - val_loss: 0.0999
# Epoch 150/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0415 - val_loss: 0.1003
# Epoch 151/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0411 - val_loss: 0.0997
# Epoch 152/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0407 - val_loss: 0.0997
# Epoch 153/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0402 - val_loss: 0.0994
# Epoch 154/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0398 - val_loss: 0.0993
# Epoch 155/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0394 - val_loss: 0.0990
# Epoch 156/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0390 - val_loss: 0.0990
# Epoch 157/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0387 - val_loss: 0.0987
# Epoch 158/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0383 - val_loss: 0.0988
# Epoch 159/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0380 - val_loss: 0.0984
# Epoch 160/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0377 - val_loss: 0.0986
# Epoch 161/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0374 - val_loss: 0.0981
# Epoch 162/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0370 - val_loss: 0.0983
# Epoch 163/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0368 - val_loss: 0.0979
# Epoch 164/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0365 - val_loss: 0.0982
# Epoch 165/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0363 - val_loss: 0.0977
# Epoch 166/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0360 - val_loss: 0.0980
# Epoch 167/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0358 - val_loss: 0.0974
# Epoch 168/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0354 - val_loss: 0.0979
# Epoch 169/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0352 - val_loss: 0.0972
# Epoch 170/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0349 - val_loss: 0.0975
# Epoch 171/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0347 - val_loss: 0.0972
# Epoch 172/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0344 - val_loss: 0.0973
# Epoch 173/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0342 - val_loss: 0.0971
# Epoch 174/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0339 - val_loss: 0.0968
# Epoch 175/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0338 - val_loss: 0.0972
# Epoch 176/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0335 - val_loss: 0.0965
# Epoch 177/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0334 - val_loss: 0.0972
# Epoch 178/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0332 - val_loss: 0.0962
# Epoch 179/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0330 - val_loss: 0.0972
# Epoch 180/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0328 - val_loss: 0.0963
# Epoch 181/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0328 - val_loss: 0.0974
# Epoch 182/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0327 - val_loss: 0.0958
# Epoch 183/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0327 - val_loss: 0.0974
# Epoch 184/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0325 - val_loss: 0.0957
# Epoch 185/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0324 - val_loss: 0.0978
# Epoch 186/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0323 - val_loss: 0.0953
# Epoch 187/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0320 - val_loss: 0.0970
# Epoch 188/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0318 - val_loss: 0.0955
# Epoch 189/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0318 - val_loss: 0.0973
# Epoch 190/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0319 - val_loss: 0.0951
# Epoch 191/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0315 - val_loss: 0.0962
# Epoch 192/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0311 - val_loss: 0.0953
# Epoch 193/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0307 - val_loss: 0.0961
# Epoch 194/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0304 - val_loss: 0.0947
# Epoch 195/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0302 - val_loss: 0.0954
# Epoch 196/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0301 - val_loss: 0.0950
# Epoch 197/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0300 - val_loss: 0.0956
# Epoch 198/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0298 - val_loss: 0.0947
# Epoch 199/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0296 - val_loss: 0.0954
# Epoch 200/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0296 - val_loss: 0.0945
# Epoch 201/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0293 - val_loss: 0.0944
# Epoch 202/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0291 - val_loss: 0.0950
# Epoch 203/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0293 - val_loss: 0.0942
# Epoch 204/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0294 - val_loss: 0.0945
# Epoch 205/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0290 - val_loss: 0.0947
# Epoch 206/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0288 - val_loss: 0.0947
# Epoch 207/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0285 - val_loss: 0.0937
# Epoch 208/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0286 - val_loss: 0.0948
# Epoch 209/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0284 - val_loss: 0.0936
# Epoch 210/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0281 - val_loss: 0.0946
# Epoch 211/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0280 - val_loss: 0.0936
# Epoch 212/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0279 - val_loss: 0.0943
# Epoch 213/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0278 - val_loss: 0.0941
# Epoch 214/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0276 - val_loss: 0.0941
# Epoch 215/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0273 - val_loss: 0.0927
# Epoch 216/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0268 - val_loss: 0.0943
# Epoch 217/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0266 - val_loss: 0.0927
# Epoch 218/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0265 - val_loss: 0.0941
# Epoch 219/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0262 - val_loss: 0.0929
# Epoch 220/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0259 - val_loss: 0.0932
# Epoch 221/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0257 - val_loss: 0.0928
# Epoch 222/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0255 - val_loss: 0.0935
# Epoch 223/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0256 - val_loss: 0.0928
# Epoch 224/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0254 - val_loss: 0.0932
# Epoch 225/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0249 - val_loss: 0.0923
# Epoch 226/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0248 - val_loss: 0.0933
# Epoch 227/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0247 - val_loss: 0.0930
# Epoch 228/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0245 - val_loss: 0.0927
# Epoch 229/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0243 - val_loss: 0.0929
# Epoch 230/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0241 - val_loss: 0.0929
# Epoch 231/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0240 - val_loss: 0.0926
# Epoch 232/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0240 - val_loss: 0.0928
# Epoch 233/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0238 - val_loss: 0.0921
# Epoch 234/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0236 - val_loss: 0.0930
# Epoch 235/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0235 - val_loss: 0.0924
# Epoch 236/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0233 - val_loss: 0.0924
# Epoch 237/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0232 - val_loss: 0.0928
# Epoch 238/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0230 - val_loss: 0.0920
# Epoch 239/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0229 - val_loss: 0.0926
# Epoch 240/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0228 - val_loss: 0.0926
# Epoch 241/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0229 - val_loss: 0.0924
# Epoch 242/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0226 - val_loss: 0.0921
# Epoch 243/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0225 - val_loss: 0.0926
# Epoch 244/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0223 - val_loss: 0.0920
# Epoch 245/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0224 - val_loss: 0.0927
# Epoch 246/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0221 - val_loss: 0.0914
# Epoch 247/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0221 - val_loss: 0.0926
# Epoch 248/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0219 - val_loss: 0.0920
# Epoch 249/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0220 - val_loss: 0.0922
# Epoch 250/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0219 - val_loss: 0.0917
# Epoch 251/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0219 - val_loss: 0.0923
# Epoch 252/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0217 - val_loss: 0.0909
# Epoch 253/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0217 - val_loss: 0.0920
# Epoch 254/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0214 - val_loss: 0.0907
# Epoch 255/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0215 - val_loss: 0.0920
# Epoch 256/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0213 - val_loss: 0.0906
# Epoch 257/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0212 - val_loss: 0.0919
# Epoch 258/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0210 - val_loss: 0.0912
# Epoch 259/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0210 - val_loss: 0.0922
# Epoch 260/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0209 - val_loss: 0.0905
# Epoch 261/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0206 - val_loss: 0.0922
# Epoch 262/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0205 - val_loss: 0.0905
# Epoch 263/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0203 - val_loss: 0.0920
# Epoch 264/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0202 - val_loss: 0.0906
# Epoch 265/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0201 - val_loss: 0.0915
# Epoch 266/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0200 - val_loss: 0.0905
# Epoch 267/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0198 - val_loss: 0.0911
# Epoch 268/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0199 - val_loss: 0.0900
# Epoch 269/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0198 - val_loss: 0.0910
# Epoch 270/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0196 - val_loss: 0.0894
# Epoch 271/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0193 - val_loss: 0.0905
# Epoch 272/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0191 - val_loss: 0.0899
# Epoch 273/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0189 - val_loss: 0.0907
# Epoch 274/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0188 - val_loss: 0.0900
# Epoch 275/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0188 - val_loss: 0.0909
# Epoch 276/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187 - val_loss: 0.0905
# Epoch 277/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0189 - val_loss: 0.0910
# Epoch 278/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0189 - val_loss: 0.0898
# Epoch 279/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0191 - val_loss: 0.0913
# Epoch 280/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0189 - val_loss: 0.0895
# Epoch 281/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0189 - val_loss: 0.0905
# Epoch 282/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0187 - val_loss: 0.0897
# Epoch 283/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187 - val_loss: 0.0904
# Epoch 284/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0186 - val_loss: 0.0896
# Epoch 285/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0186 - val_loss: 0.0904
# Epoch 286/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185 - val_loss: 0.0899
# Epoch 287/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0185 - val_loss: 0.0906
# Epoch 288/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0184 - val_loss: 0.0893
# Epoch 289/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182 - val_loss: 0.0904
# Epoch 290/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178 - val_loss: 0.0897
# Epoch 291/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0177 - val_loss: 0.0900
# Epoch 292/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0175 - val_loss: 0.0895
# Epoch 293/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0175 - val_loss: 0.0897
# Epoch 294/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0173 - val_loss: 0.0892
# Epoch 295/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0171 - val_loss: 0.0893
# Epoch 296/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0171 - val_loss: 0.0890
# Epoch 297/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169 - val_loss: 0.0894
# Epoch 298/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0167 - val_loss: 0.0889
# Epoch 299/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0165 - val_loss: 0.0895
# Epoch 300/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0163 - val_loss: 0.0895
# Epoch 301/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0162 - val_loss: 0.0896
# Epoch 302/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0161 - val_loss: 0.0891
# Epoch 303/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0160 - val_loss: 0.0894
# Epoch 304/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0158 - val_loss: 0.0889
# Epoch 305/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0157 - val_loss: 0.0891
# Epoch 306/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0156 - val_loss: 0.0888
# Epoch 307/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0155 - val_loss: 0.0893
# Epoch 308/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153 - val_loss: 0.0890
# Epoch 309/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153 - val_loss: 0.0890
# Epoch 310/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0152 - val_loss: 0.0892
# Epoch 311/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0152 - val_loss: 0.0890
# Epoch 312/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0151 - val_loss: 0.0888
# Epoch 313/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - val_loss: 0.0888
# Epoch 314/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - val_loss: 0.0893
# Epoch 315/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149 - val_loss: 0.0890
# Epoch 316/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150 - val_loss: 0.0898
# Epoch 317/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - val_loss: 0.0894
# Epoch 318/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - val_loss: 0.0901
# Epoch 319/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - val_loss: 0.0892
# Epoch 320/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0149 - val_loss: 0.0896
# Epoch 321/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0148 - val_loss: 0.0891
# Epoch 322/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147 - val_loss: 0.0894
# Epoch 323/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0146 - val_loss: 0.0887
# Epoch 324/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0146 - val_loss: 0.0895
# Epoch 325/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0144 - val_loss: 0.0890
# Epoch 326/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144 - val_loss: 0.0892
# Epoch 327/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143 - val_loss: 0.0885
# Epoch 328/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0143 - val_loss: 0.0891
# Epoch 329/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141 - val_loss: 0.0884
# Epoch 330/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141 - val_loss: 0.0887
# Epoch 331/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0140 - val_loss: 0.0887
# Epoch 332/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0139 - val_loss: 0.0892
# Epoch 333/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138 - val_loss: 0.0888
# Epoch 334/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0137 - val_loss: 0.0892
# Epoch 335/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137 - val_loss: 0.0888
# Epoch 336/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - val_loss: 0.0890
# Epoch 337/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135 - val_loss: 0.0883
# Epoch 338/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - val_loss: 0.0889
# Epoch 339/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - val_loss: 0.0883
# Epoch 340/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - val_loss: 0.0890
# Epoch 341/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133 - val_loss: 0.0883
# Epoch 342/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0132 - val_loss: 0.0892
# Epoch 343/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133 - val_loss: 0.0883
# Epoch 344/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - val_loss: 0.0888
# Epoch 345/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133 - val_loss: 0.0884
# Epoch 346/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0135 - val_loss: 0.0894
# Epoch 347/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134 - val_loss: 0.0886
# Epoch 348/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0136 - val_loss: 0.0895
# Epoch 349/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - val_loss: 0.0892
# Epoch 350/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0135 - val_loss: 0.0893
# Epoch 351/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0134 - val_loss: 0.0888
# Epoch 352/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0133 - val_loss: 0.0887
# Epoch 353/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0131 - val_loss: 0.0886
# Epoch 354/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130 - val_loss: 0.0883
# Epoch 355/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0129 - val_loss: 0.0883
# Epoch 356/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0128 - val_loss: 0.0885
# Epoch 357/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0127 - val_loss: 0.0882
# Epoch 358/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126 - val_loss: 0.0882
# Epoch 359/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0125 - val_loss: 0.0881
# Epoch 360/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124 - val_loss: 0.0884
# Epoch 361/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0124 - val_loss: 0.0881
# Epoch 362/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124 - val_loss: 0.0883
# Epoch 363/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - val_loss: 0.0885
# Epoch 364/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0123 - val_loss: 0.0885
# Epoch 365/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0122 - val_loss: 0.0883
# Epoch 366/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121 - val_loss: 0.0883
# Epoch 367/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0120 - val_loss: 0.0882
# Epoch 368/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - val_loss: 0.0880
# Epoch 369/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0119 - val_loss: 0.0880
# Epoch 370/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0119 - val_loss: 0.0879
# Epoch 371/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0118 - val_loss: 0.0881
# Epoch 372/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0117 - val_loss: 0.0877
# Epoch 373/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116 - val_loss: 0.0881
# Epoch 374/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0115 - val_loss: 0.0879
# Epoch 375/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0114 - val_loss: 0.0882
# Epoch 376/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - val_loss: 0.0877
# Epoch 377/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0113 - val_loss: 0.0884
# Epoch 378/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0112 - val_loss: 0.0880
# Epoch 379/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0111 - val_loss: 0.0882
# Epoch 380/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110 - val_loss: 0.0878
# Epoch 381/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0109 - val_loss: 0.0883
# Epoch 382/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0109 - val_loss: 0.0877
# Epoch 383/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0108 - val_loss: 0.0880
# Epoch 384/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0108 - val_loss: 0.0877
# Epoch 385/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0107 - val_loss: 0.0879
# Epoch 386/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0107 - val_loss: 0.0876
# Epoch 387/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0106 - val_loss: 0.0879
# Epoch 388/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0105 - val_loss: 0.0879
# Epoch 389/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - val_loss: 0.0882
# Epoch 390/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0104 - val_loss: 0.0879
# Epoch 391/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0104 - val_loss: 0.0882
# Epoch 392/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0103 - val_loss: 0.0881
# Epoch 393/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0103 - val_loss: 0.0880
# Epoch 394/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - val_loss: 0.0878
# Epoch 395/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - val_loss: 0.0883
# Epoch 396/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - val_loss: 0.0879
# Epoch 397/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0102 - val_loss: 0.0882
# Epoch 398/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - val_loss: 0.0879
# Epoch 399/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - val_loss: 0.0882
# Epoch 400/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - val_loss: 0.0875
# Epoch 401/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - val_loss: 0.0881
# Epoch 402/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0101 - val_loss: 0.0877
# Epoch 403/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100 - val_loss: 0.0883
# Epoch 404/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100 - val_loss: 0.0878
# Epoch 405/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0100 - val_loss: 0.0884
# Epoch 406/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - val_loss: 0.0880
# Epoch 407/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - val_loss: 0.0886
# Epoch 408/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0099 - val_loss: 0.0874
# Epoch 409/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098 - val_loss: 0.0884
# Epoch 410/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0098 - val_loss: 0.0878
# Epoch 411/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097 - val_loss: 0.0880
# Epoch 412/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0097 - val_loss: 0.0875
# Epoch 413/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - val_loss: 0.0886
# Epoch 414/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - val_loss: 0.0875
# Epoch 415/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096 - val_loss: 0.0881
# Epoch 416/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - val_loss: 0.0877
# Epoch 417/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - val_loss: 0.0882
# Epoch 418/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0095 - val_loss: 0.0875
# Epoch 419/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - val_loss: 0.0883
# Epoch 420/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0095 - val_loss: 0.0877
# Epoch 421/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0094 - val_loss: 0.0886
# Epoch 422/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093 - val_loss: 0.0877
# Epoch 423/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - val_loss: 0.0881
# Epoch 424/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0878
# Epoch 425/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - val_loss: 0.0884
# Epoch 426/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093 - val_loss: 0.0869
# Epoch 427/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0093 - val_loss: 0.0886
# Epoch 428/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - val_loss: 0.0878
# Epoch 429/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092 - val_loss: 0.0879
# Epoch 430/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0876
# Epoch 431/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0888
# Epoch 432/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0093 - val_loss: 0.0870
# Epoch 433/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0093 - val_loss: 0.0884
# Epoch 434/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0876
# Epoch 435/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0881
# Epoch 436/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0875
# Epoch 437/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0883
# Epoch 438/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0092 - val_loss: 0.0871
# Epoch 439/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0092 - val_loss: 0.0889
# Epoch 440/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091 - val_loss: 0.0869
# Epoch 441/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0878
# Epoch 442/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090 - val_loss: 0.0876
# Epoch 443/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0879
# Epoch 444/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0090 - val_loss: 0.0866
# Epoch 445/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0889
# Epoch 446/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0870
# Epoch 447/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0877
# Epoch 448/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - val_loss: 0.0874
# Epoch 449/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0088 - val_loss: 0.0880
# Epoch 450/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088 - val_loss: 0.0869
# Epoch 451/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0089 - val_loss: 0.0881
# Epoch 452/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088 - val_loss: 0.0870
# Epoch 453/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088 - val_loss: 0.0881
# Epoch 454/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0087 - val_loss: 0.0869
# Epoch 455/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0873
# Epoch 456/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - val_loss: 0.0872
# Epoch 457/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - val_loss: 0.0877
# Epoch 458/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0085 - val_loss: 0.0864
# Epoch 459/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0084 - val_loss: 0.0880
# Epoch 460/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0083 - val_loss: 0.0869
# Epoch 461/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0870
# Epoch 462/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0082 - val_loss: 0.0872
# Epoch 463/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - val_loss: 0.0877
# Epoch 464/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082 - val_loss: 0.0865
# Epoch 465/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0081 - val_loss: 0.0876
# Epoch 466/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080 - val_loss: 0.0870
# Epoch 467/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080 - val_loss: 0.0872
# Epoch 468/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0079 - val_loss: 0.0871
# Epoch 469/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079 - val_loss: 0.0871
# Epoch 470/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 0.0870
# Epoch 471/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0078 - val_loss: 0.0873
# Epoch 472/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - val_loss: 0.0866
# Epoch 473/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077 - val_loss: 0.0873
# Epoch 474/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - val_loss: 0.0873
# Epoch 475/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - val_loss: 0.0867
# Epoch 476/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0076 - val_loss: 0.0874
# Epoch 477/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075 - val_loss: 0.0873
# Epoch 478/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - val_loss: 0.0868
# Epoch 479/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075 - val_loss: 0.0872
# Epoch 480/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075 - val_loss: 0.0874
# Epoch 481/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - val_loss: 0.0868
# Epoch 482/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0075 - val_loss: 0.0875
# Epoch 483/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - val_loss: 0.0870
# Epoch 484/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0075 - val_loss: 0.0872
# Epoch 485/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0074 - val_loss: 0.0871
# Epoch 486/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - val_loss: 0.0871
# Epoch 487/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - val_loss: 0.0869
# Epoch 488/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0074 - val_loss: 0.0876
# Epoch 489/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0866
# Epoch 490/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - val_loss: 0.0874
# Epoch 491/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0073 - val_loss: 0.0872
# Epoch 492/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0073 - val_loss: 0.0870
# Epoch 493/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - val_loss: 0.0870
# Epoch 494/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0073 - val_loss: 0.0875
# Epoch 495/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0072 - val_loss: 0.0867
# Epoch 496/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - val_loss: 0.0873
# Epoch 497/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - val_loss: 0.0871
# Epoch 498/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0072 - val_loss: 0.0870
# Epoch 499/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - val_loss: 0.0871
# Epoch 500/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0071 - val_loss: 0.0871
# Epoch 501/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070 - val_loss: 0.0868
# Epoch 502/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - val_loss: 0.0873
# Epoch 503/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0070 - val_loss: 0.0869
# Epoch 504/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070 - val_loss: 0.0870
# Epoch 505/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069 - val_loss: 0.0873
# Epoch 506/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069 - val_loss: 0.0869
# Epoch 507/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0870
# Epoch 508/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0873
# Epoch 509/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068 - val_loss: 0.0869
# Epoch 510/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0068 - val_loss: 0.0869
# Epoch 511/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0067 - val_loss: 0.0875
# Epoch 512/512
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067 - val_loss: 0.0868

# %%
# Assuming model is your trained Keras model and x_data, y_data are your input features and target values
y_pred = autoencoder.predict(y_data_scaled)

# Calculate Mean Squared Error
mse = mean_squared_error(y_data_scaled, y_pred)
print(f"Mean Squared Error: {mse}")
print("r2_score: ", r2_score(y_data_scaled,y_pred,  multioutput='uniform_average'))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Mean Squared Error: 0.018694519170392724
# r2_score:  0.9820463691436746

# %% [markdown]
# # Save model

# %%
# autoencoder.save_weights('autoencoder2_weights.weights.h5')
# autoencoder.save('autoencoder2.keras')

# %% [markdown]
# # Load model

# %%
autoencoder = create_model2()  # Recreate the model architecture
autoencoder.load_weights('autoencoder2_weights.weights.h5')
# Out:
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL-Oct2024\Lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'SGD', because it has 2 variables whereas the saved optimizer has 22 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# # Encoder with Attention layers

# %%
# dim = y_data.shape[1]
# input_dimension = len(ys_data[0:dim])
# # ys_data=ys_data.tolist()
# output_dimension = len(ys_data[0:dim])
# def create_model3(units=units, activation=activation):

#     # Define the input
#     input_layer = Input(shape=(dim,), name='input')

#     # Encoder
#     encoder = Dense(units, activation=activation, name='0')(input_layer)
#     encoder = Dense(units // 2, activation=activation, name='1')(encoder)
#     encoder = Dense(units // 4, activation=activation, name='2')(encoder)
#     encoder = Dense(units // 8, activation=activation, name='3')(encoder)
    
#     # Attention layer in the encoder
#     query_enc = Dense(units // 32, activation='relu', name='query_enc')(encoder)
#     key_enc = Dense(units // 32, activation='relu', name='key_enc')(encoder)
#     value_enc = Dense(units // 32, activation='relu', name='value_enc')(encoder)
#     attention_enc = Attention(name='attention_enc')([query_enc, value_enc, key_enc])
#     encoder_output = Concatenate(name='encoder_output')([encoder, attention_enc])
    
#     model = Model(inputs=input_layer, outputs=encoder_output, name='encoder')

#     optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
#     model.compile(optimizer=optimizer, loss=loss)
#     return model

# encoder = create_model3()
# encoder.summary()



# for layer in autoencoder.layers:
#     if isinstance(layer, Dense):
#         try:
#             # Only set weights if the layer exists in the new model
#             new_layer = encoder.get_layer(name=layer.name)
#             weights = layer.get_weights()
#             new_layer.set_weights(weights)
#         except ValueError:
#             # Skip layers that do not have corresponding layers in the new model
#             print(f"Skipping weight transfer for layer: {layer.name}")

# optimizer = SGD(learning_rate = learning_rate, momentum=momentum)
# encoder.compile(optimizer=optimizer, loss=loss)

# predictions = encoder.predict(y_data)
# predictions.shape

# %% [markdown]
# # Encoder without Attention layers

# %%
dim = y_data.shape[1]
input_dimension = len(ys_data[0:dim])
# ys_data=ys_data.tolist()
output_dimension = len(ys_data[0:dim])
def create_model3(units=units, activation=activation):

    model = Sequential()

    model.add(Dense(units, input_dim=dim, activation=activation, name = '0'))  # Adjust input_dim to match number of features
    model.add(Dense(units//2, activation=activation, name = '1'))
    model.add(Dense(units//4, activation=activation, name = '2'))
    model.add(Dense(units//8, activation=activation, name = '3'))
    model.add(Dense(units//16, activation=activation, name = '4'))
    optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=optimizer, loss=loss)
    return model

encoder = create_model3()
encoder.summary()



for layer in autoencoder.layers:
    if isinstance(layer, Dense):
        try:
            # Only set weights if the layer exists in the new model
            new_layer = encoder.get_layer(name=layer.name)
            weights = layer.get_weights()
            new_layer.set_weights(weights)
        except ValueError:
            # Skip layers that do not have corresponding layers in the new model
            print(f"Skipping weight transfer for layer: {layer.name}")

optimizer = SGD(learning_rate = learning_rate, momentum=momentum)
encoder.compile(optimizer=optimizer, loss=loss)

predictions = encoder.predict(y_data)
predictions.shape
# Out:
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ 0 (Dense)                            │ (None, 512)                 │          67,072 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 1 (Dense)                            │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 2 (Dense)                            │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 3 (Dense)                            │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 4 (Dense)                            │ (None, 32)                  │           2,080 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 241,632 (943.88 KB)
#  Trainable params: 241,632 (943.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Skipping weight transfer for layer: 5
# Skipping weight transfer for layer: 6
# Skipping weight transfer for layer: 7
# Skipping weight transfer for layer: 8
# Skipping weight transfer for layer: 9
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# (563, 32)

# %%
TF_pred = encoder.predict(y_data_scaled)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
df_TF = pd.DataFrame(TF_pred)
df_TF_x= pd.concat([df_x, df_TF], axis=1)
# df_TF_x

# %%
x_train, x_test, TF_pred_train, TF_pred_test = train_test_split(x_data, TF_pred, test_size=0.15, random_state=10)
scaler_x = StandardScaler()
scaler_x.fit(x_train)
x_train = scaler_x.transform(x_train)
x_test = scaler_x.transform(x_test)
x_data_scaled = scaler_x.transform(x_data)


# scaler_TF = MinMaxScaler()
# scaler_TF.fit(TF_pred_train)
# TF_pred_train_scaled = scaler_TF.transform(TF_pred_train)
# TF_pred_test_scaled = scaler_TF.transform(TF_pred_test)
# TF_pred_scaled = scaler_TF.transform(TF_pred)

# %%
dump(scaler_x, 'scaler_x2.bin', compress=True)
# Out:
# ['scaler_x2.bin']

# %% [markdown]
# # ANN model

# %%
Variable_dim = len(df_x.columns)
def create_model5(unit=128, activation=activation):
    
    model = Sequential()
    model.add(Dense(unit, input_dim=Variable_dim, activation=activation))  # Adjust input_dim to match number of features
    # model.add(Dense(unit, activation=activation))
    model.add(Dense(unit, activation=activation))
    model.add(Dense(unit*2, activation=activation))
    model.add(Dense(unit, activation=activation))
    model.add(Dense(encoder.output_shape[1],activation=activation))  # Output layer should match the number of features
    optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=optimizer, loss=loss)
    return model

ANN_model = create_model5()
ANN_model.summary()
# Out:
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                     │ (None, 128)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 32)                  │           4,128 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 88,352 (345.12 KB)
#  Trainable params: 88,352 (345.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epoch = 500
batch_sizes = 32
early_stopping = EarlyStopping(
    monitor='val_loss',  # You can also use 'val_accuracy'
    patience=10,  # Number of epochs to wait after the last time validation loss improved
    restore_best_weights=True  # Restores model weights from the epoch with the best validation loss
)


history = ANN_model.fit(x_train, TF_pred_train, epochs=epoch, batch_size=batch_sizes, validation_data=(x_test, TF_pred_test), callbacks=[early_stopping])

# Extract the training loss values
training_loss = history.history['loss']

# Extract the validation loss values (if available)
validation_loss = history.history['val_loss']

# Create an array of epoch numbers (or steps)
epochs = range(1, len(training_loss) + 1)

# Plot the training and validation loss vs. epochs
plt.plot(epochs, training_loss, label='Training Loss')
if validation_loss:
    plt.plot(epochs, validation_loss, label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.legend()
plt.show()

#print('Test set\n  Loss: {:0.3f}'.format(loss))
# Out:
# Epoch 1/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0430 - val_loss: 0.0769
# Epoch 2/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0771
# Epoch 3/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 4/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 5/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 6/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 7/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0429 - val_loss: 0.0768
# Epoch 8/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 9/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 10/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 11/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 12/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 13/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0767
# Epoch 14/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 15/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 16/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428 - val_loss: 0.0768
# Epoch 17/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0428 - val_loss: 0.0767
# Epoch 18/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 19/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 20/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 21/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0427 - val_loss: 0.0767
# Epoch 22/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 23/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 24/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 25/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0767
# Epoch 26/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0427 - val_loss: 0.0768
# Epoch 27/500
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0427 - val_loss: 0.0767

# %%
ANN_pred = ANN_model.predict(x_data_scaled)
print("r2_score: ", r2_score(TF_pred, ANN_pred,  multioutput='uniform_average'))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# r2_score:  0.790260664689321

# %% [markdown]
# # Save model

# %%
# ANN_model.save_weights('ANN2_weights.weights.h5')
# ANN_model.save('ANN2.keras')

# %% [markdown]
# # Load model

# %%
# ANN_model = create_model5()  # Recreate the model architecture
# ANN_model.load_weights('ANN2_weights.weights.h5')
# ANN_model = load_model('ANN2.keras')

# %% [markdown]
# # Decoder with attention layer

# %%
# dim = y_data.shape[1]
# input_dimension = len(ys_data[0:dim])
# # ys_data=ys_data.tolist()
# output_dimension = len(ys_data[0:dim])
# def create_model4(units=units, activation=activation):
    
#     input_layer = Input(shape=(encoder.output_shape[1],), name='input')

# # Decoder
#     decoder = Dense(units // 16, activation=activation, name='0')(input_layer)
#     decoder = Dense(units // 8, activation=activation, name='1')(decoder)
#     decoder = Dense(units // 4, activation=activation, name='2')(decoder)
#     decoder = Dense(units // 2, activation=activation, name='3')(decoder)
#     decoder = Dense(units, activation=activation, name='decoder_4')(decoder)

#     # Attention layer in the decoder
#     query_dec = Dense(units // 32, activation='relu', name='query_dec')(decoder)
#     key_dec = Dense(units // 32, activation='relu', name='key_dec')(decoder)
#     value_dec = Dense(units // 32, activation='relu', name='value_dec')(decoder)
#     attention_dec = Attention(name='attention_dec')([query_dec, value_dec, key_dec])
#     decoder_output = Concatenate(name='decoder_output')([decoder, attention_dec])

#     # Output layer
#     output_layer = Dense(dim, name='output')(decoder_output)

#     # Define the model
#     model = Model(inputs=input_layer, outputs=output_layer, name='decoder')
#     # Compile the model
#     optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
#     model.compile(optimizer=optimizer, loss=loss)
    
#     return model

# decoder = create_model4()
# decoder.summary()



# for layer in autoencoder.layers:
#     if isinstance(layer, Dense):
#         try:
#             # Only set weights if the layer exists in the new model
#             new_layer = decoder.get_layer(name=layer.name)
#             weights = layer.get_weights()
#             new_layer.set_weights(weights)
#         except ValueError:
#             # Skip layers that do not have corresponding layers in the new model
#             print(f"Skipping weight transfer for layer: {layer.name}")

# optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
# decoder.compile(optimizer=optimizer, loss=loss)

# # predictions = decoder.predict(y_data)
# # predictions.shape

# %% [markdown]
# # Decoder

# %%
dim = y_data.shape[1]
input_dimension = len(ys_data[0:dim])
# ys_data=ys_data.tolist()
output_dimension = len(ys_data[0:dim])
def create_model4(units=units, activation=activation):

    model = Sequential()

    model.add(Dense(units//8, input_dim=int(units/16), activation=activation, name = '5'))  # Adjust input_dim to match number of features
    model.add(Dense(units//4, activation=activation, name = '6'))
    model.add(Dense(units//2, activation=activation, name = '7'))
    model.add(Dense(units, activation=activation, name = '8'))
    model.add(Dense(dim, name = '9'))  # Output layer should match the number of features
    optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
    model.compile(optimizer=optimizer, loss=loss)
    return model

decoder = create_model4()
decoder.summary()



for layer in autoencoder.layers:
    if isinstance(layer, Dense):
        try:
            # Only set weights if the layer exists in the new model
            new_layer = decoder.get_layer(name=layer.name)
            weights = layer.get_weights()
            new_layer.set_weights(weights)
        except ValueError:
            # Skip layers that do not have corresponding layers in the new model
            print(f"Skipping weight transfer for layer: {layer.name}")

optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
decoder.compile(optimizer=optimizer, loss=loss)

# predictions = decoder.predict(y_data)
# predictions.shape
# Out:
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ 5 (Dense)                            │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 6 (Dense)                            │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 7 (Dense)                            │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 8 (Dense)                            │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ 9 (Dense)                            │ (None, 130)                 │          66,690 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 241,730 (944.26 KB)
#  Trainable params: 241,730 (944.26 KB)
#  Non-trainable params: 0 (0.00 B)
# Skipping weight transfer for layer: 0
# Skipping weight transfer for layer: 1
# Skipping weight transfer for layer: 2
# Skipping weight transfer for layer: 3
# Skipping weight transfer for layer: 4

# %%
decoder.input_shape
# Out:
# (None, 32)

# %% [markdown]
# # ANN + Decoder Model

# %%
combined_output = decoder(ANN_model.outputs)

# Define the new cascaded model
ANN_decoder = Model(inputs=ANN_model.inputs, outputs=combined_output)

# Compile the new model
optimizer = SGD(learning_rate=learning_rate, momentum=momentum)
ANN_decoder.compile(optimizer=optimizer, loss=loss)
ANN_decoder.save('ANN_decoder2.keras')
ANN_decoder.summary()
# Out:
# Model: "functional_109"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)          │ (None, 13)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 128)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 32)                  │           4,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_16 (Sequential)           │ (None, 130)                 │         241,730 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 330,082 (1.26 MB)
#  Trainable params: 330,082 (1.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Get the output of the cascaded model
output = ANN_decoder.predict(x_data_scaled)
s11_reconstructed = scaler_y.inverse_transform(output)
# print(s11_reconstructed)
print("r2_score: ", r2_score(y_data,s11_reconstructed,multioutput='uniform_average'))
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_386']
# Received: inputs=Tensor(shape=(32, 13))
#   warnings.warn(msg)
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_419
# Received: inputs=['Tensor(shape=(32, 32))']
#   warnings.warn(msg)
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_386']
# Received: inputs=Tensor(shape=(None, 13))
#   warnings.warn(msg)
# C:\Users\msalmaniaran\AppData\Local\anaconda3\envs\RL_Test\lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_419
# Received: inputs=['Tensor(shape=(None, 32))']
#   warnings.warn(msg)
# r2_score:  0.8454305624215462

# %%
x_data_scaled[40]
# Out:
# array([0.34592151, 0.37705457, 0.44227759, 0.25295786, 0.39611778,
#        0.18922199, 0.3750461 , 0.43678424, 2.20953998, 0.55155603,
#        0.4566234 , 0.25838881, 0.21225554])

# %%
from scipy.signal import savgol_filter
i = random.randint(0,len(x_data)-1)
# i = 582
print("sample number: ", i)
threshold = -4  # Define the threshold
window_length = 5
polyorder = 1
data = s11_reconstructed[i]
y_smooth = np.copy(data)
indices_above_threshold = np.where(data > threshold)[0]
if len(indices_above_threshold) > window_length:  # Ensure there are enough points to apply the filter
    y_smooth[indices_above_threshold] = savgol_filter(data[indices_above_threshold], window_length=window_length, polyorder=polyorder)



# print(data)

# y_smooth = savgol_filter(s11_reconstructed[i], window_length=7, polyorder=2)
# y_smooth2 = gaussian_filter1d(s11_reconstructed[i], sigma=1)

# Y = fft(s11_reconstructed[i])
# cutoff = 1300
# Y[cutoff:] = 0
# y_smooth3 = np.real(ifft(Y))


print(r2_score(y_data[i],s11_reconstructed[i],  multioutput='uniform_average'))
print(r2_score(y_data[i],y_smooth,  multioutput='uniform_average'))

clipped_data = [min(x, 0) for x in y_smooth]

plt.plot(freq, s11_reconstructed[i], label = 'predicted')
plt.plot(freq, clipped_data, label = 'Clipped Savitzky-Golay')
# plt.plot(freq, y_smooth2, label = 'Gaussian Filter')
# plt.plot(freq, y_smooth3, label = 'FFT')
plt.plot(freq, y_data[i], 'r', label = 'actual')

# Adding labels, title, and legend
plt.xlabel('Frequency')
plt.ylabel('S11')
plt.title('Line Graph of Reconstructed and Actual S11')
plt.legend()  # Show legend
plt.grid(True)
plt.show()
# Out:
# sample number:  424
# 0.9640708003484153
# 0.9637494358803518

# %%
s11_smoothed=[]
for i in range(len(s11_reconstructed)):
    data = s11_reconstructed[i]
    y_smooth = np.copy(data)
    indices_above_threshold = np.where(data > threshold)[0]
    if len(indices_above_threshold) > window_length:  # Ensure there are enough points to apply the filter
        y_smooth[indices_above_threshold] = savgol_filter(data[indices_above_threshold], window_length=window_length, polyorder=polyorder)
    s11_smoothed.append(y_smooth)

# %%
print("r2_score: ", r2_score(y_data,s11_smoothed,multioutput='uniform_average'))
# Out:
# r2_score:  0.8463649350944943

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create sample noisy data
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(0, 0.5, x.shape)

# Apply moving average
window_size = 5
y_smooth = np.convolve(y, np.ones(window_size)/window_size, mode='same')

plt.plot(x, y, label='Noisy')
plt.plot(x, y_smooth, label='Smoothed', linewidth=2)
plt.legend()
plt.show()

# %%
from scipy.signal import savgol_filter

# Apply Savitzky-Golay filter
y_smooth = savgol_filter(y, window_length=5, polyorder=3)

plt.plot(x, y, label='Noisy')
plt.plot(x, y_smooth, label='Savitzky-Golay', linewidth=2)
plt.legend()
plt.show()

# %%
from scipy.ndimage import gaussian_filter1d

# Apply Gaussian filter
y_smooth = gaussian_filter1d(y, sigma=2)

plt.plot(x, y, label='Noisy')
plt.plot(x, y_smooth, label='Gaussian Filter', linewidth=2)
plt.legend()
plt.show()

# %%
from scipy.fft import fft, ifft

# Perform Fourier transform
Y = fft(y)

# Zero out high frequency components
cutoff = 60
Y[cutoff:] = 0

# Inverse Fourier transform to get smoothed data
y_smooth = np.real(ifft(Y))

plt.plot(x, y, label='Noisy')
plt.plot(x, y_smooth, label='Low-pass Filter', linewidth=2)
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter

# Create sample noisy data with deep points
x = np.linspace(0, 20, 500)
y = np.sin(x) + np.random.normal(0, 0.2, x.shape)
y[100:120] = -2  # Adding an artificial deep point

# Apply Savitzky-Golay filter
y_smooth = savgol_filter(y, window_length=31, polyorder=3)

plt.plot(x, y, label='Noisy Data with Deep Points', alpha=0.6)
plt.plot(x, y_smooth, label='Savitzky-Golay Smoothed', linewidth=2, color='red')
plt.legend()
plt.show()

# %%
j = 0
highQ_index = []
index_lowR2 = []
for i in range(len(y_data)):
    r2 = r2_score(y_data[i],s11_reconstructed[i],  multioutput='variance_weighted')
    if r2<=0.3:
        highQ_index.append(i)
        index_lowR2.append(i)
        j+=1
print(j)
print(index_lowR2)
# Out:
# 9
# [61, 64, 72, 211, 257, 329, 408, 488, 559]

# %%
# highQ_index

# %%
input_dimension = len(x_data[0])
# ys_data=ys_data.tolist()
output_dimension = len(ys_data[0:250])
def create_model(units=64, activation='relu'):
    # Define the input layer
    input_layer = Input(shape=(input_dimension,))

    # Define the shared hidden layers
    hidden_layer = Dense(units, activation=activation)(input_layer)
    # hidden_layer = Dense(units, activation=activation)(input_layer)
    hidden_layer = Dense(2*units, activation=activation)(hidden_layer)
    # hidden_layer = Dense(3*units, activation=activation)(hidden_layer)
    # hidden_layer = Dense(units, activation=activation)(hidden_layer)

    # Define the first output layer
    output = Dense(output_dimension, activation='linear')(hidden_layer)

    # Create the model with multiple outputs
    model = Model(inputs=input_layer, outputs=output)


    optimizer = SGD(learning_rate=0.01, momentum=0.9)
    model.compile(optimizer=optimizer, loss='mean_absolute_error')
    return model

simulation = create_model()
simulation.summary()
print('x_data dimension: ',x_data.size)
print('y_data dimension: ',y_data.size)
print('x1_train dimension: ',x_train.size)
print('y_train dimension: ',y_train.size)
print('x1_test dimension: ',x_test.size)
print('y_test dimension: ',y_test.size)
# Out:
# Model: "model_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_33 (InputLayer)       [(None, 16)]              0
#
#  dense_122 (Dense)           (None, 64)                1088
#
#  dense_123 (Dense)           (None, 128)               8320
#
#  dense_124 (Dense)           (None, 250)               32250
#
# =================================================================
# Total params: 41,658
# Trainable params: 41,658
# Non-trainable params: 0
# _________________________________________________________________
# x_data dimension:  10128
# y_data dimension:  158250
# x1_train dimension:  31520
# y_train dimension:  492500
# x1_test dimension:  7888
# y_test dimension:  123250

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=20)
scaler_x = MinMaxScaler()
scaler_x.fit(x_train)
x_train = scaler_x.transform(x_train)
x_test = scaler_x.transform(x_test)

x_data_scaled = scaler_x.transform(x_data)


scaler_y = MinMaxScaler()
scaler_y.fit(y_train)
y_train = scaler_y.transform(y_train)
y_test = scaler_y.transform(y_test)
y_data_scaled = scaler_y.transform(y_data)
print(x_test)
# Out:
# [[0.1875     0.41766667 0.91       ... 0.53111111 0.         0.        ]
#  [0.4575     0.41766667 0.91       ... 0.53111111 0.         0.        ]
#  [0.4575     0.41766667 0.91       ... 0.53111111 0.         0.        ]
#  ...
#  [0.4575     0.41766667 0.91       ... 0.53111111 0.         0.        ]
#  [0.4575     0.41766667 0.91       ... 0.53111111 0.         0.        ]
#  [0.4575     0.41766667 0.91       ... 0.53111111 0.         0.        ]]

# %%
epoch = 128
batch_sizes = 128
history = simulation.fit(x_train, y_train, epochs=epoch, batch_size=batch_sizes, validation_data=(x_test, y_test))

# Extract the training loss values
training_loss = history.history['loss']

# Extract the validation loss values (if available)
validation_loss = history.history['val_loss']

# Create an array of epoch numbers (or steps)
epochs = range(1, len(training_loss) + 1)

# Plot the training and validation loss vs. epochs
plt.plot(epochs, training_loss, label='Training Loss')
if validation_loss:
    plt.plot(epochs, validation_loss, label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.legend()
plt.show()

#loss = CenterFrequency.evaluate(x1_test,y1_test, verbose=1)
#print('Test set\n  Loss: {:0.3f}'.format(loss))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2169], line 3
#       1 epoch = 128
#       2 batch_sizes = 128
# ----> 3 history = simulation.fit(x_train, y_train, epochs=epoch, batch_size=batch_sizes, validation_data=(x_test, y_test))
#       5 # Extract the training loss values
#       6 training_loss = history.history['loss']
#
# File ~\AppData\Local\anaconda3\envs\Quantum\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\anaconda3\envs\Quantum\lib\site-packages\keras\engine\data_adapter.py:1852, in _check_data_cardinality(data)
#    1845     msg += "  {} sizes: {}\n".format(
#    1846         label,
#    1847         ", ".join(
#    1848             str(i.shape[0]) for i in tf.nest.flatten(single_data)
#    1849         ),
#    1850     )
#    1851 msg += "Make sure all arrays contain the same number of samples."
# -> 1852 raise ValueError(msg)
#
# ValueError: Data cardinality is ambiguous:
#   x sizes: 540
#   y sizes: 508
# Make sure all arrays contain the same number of samples.

# %%
# Assuming model is your trained Keras model and x_data, y_data are your input features and target values
y_pred = simulation.predict(x_data_scaled)

# Calculate Mean Squared Error
mse = mean_squared_error(y_data_scaled, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# 20/20 [==============================] - 0s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2170], line 5
#       2 y_pred = simulation.predict(x_data_scaled)
#       4 # Calculate Mean Squared Error
# ----> 5 mse = mean_squared_error(y_data_scaled, y_pred)
#       6 print(f"Mean Squared Error: {mse}")
#
# File ~\AppData\Local\anaconda3\envs\Quantum\lib\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\AppData\Local\anaconda3\envs\Quantum\lib\site-packages\sklearn\metrics\_regression.py:474, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     404 @validate_params(
#     405     {
#     406         "y_true": ["array-like"],
#    (...)
#     415     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     416 ):
#     417     """Mean squared error regression loss.
#     418
#     419     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     472     0.825...
#     473     """
# --> 474     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     475         y_true, y_pred, multioutput
#     476     )
#     477     check_consistent_length(y_true, y_pred, sample_weight)
#     478     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~\AppData\Local\anaconda3\envs\Quantum\lib\site-packages\sklearn\metrics\_regression.py:110, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#     107     y_pred = y_pred.reshape((-1, 1))
#     109 if y_true.shape[1] != y_pred.shape[1]:
# --> 110     raise ValueError(
#     111         "y_true and y_pred have different number of output ({0}!={1})".format(
#     112             y_true.shape[1], y_pred.shape[1]
#     113         )
#     114     )
#     116 n_outputs = y_true.shape[1]
#     117 allowed_multioutput_str = ("raw_values", "uniform_average", "variance_weighted")
#
# ValueError: y_true and y_pred have different number of output (170!=250)

# %%
random_sample = random.randint(0, len(df_all))
# Getting predictions for the new data
new_data = x_data[random_sample].reshape(1, -1)
prediction = simulation.predict(scaler_x.transform(new_data))

prediction = scaler_y.inverse_transform(prediction)
# The 'predictions' variable will contain the predicted outputs for your new data
# print(prediction)

yf=np.squeeze(yf_data[:len(df_yst.columns)])
df_1 = pd.DataFrame(yf, columns=['Frequency'])
prediction=np.squeeze(prediction)
df_2 = pd.DataFrame(prediction, columns=['S11'])
y_actual = y_data[random_sample]
df_3 = pd.DataFrame(y_actual, columns=['Actual'])

df_pre_concat = pd.concat([df_1, df_2], axis=1)
# df_pre_concat.plot(x='Frequency', y='S11', kind='line')

df_pre_concat2 = pd.concat([df_1, df_3], axis=1)
# df_pre_concat.plot(x='Frequency', y='Actual', kind='line')


plt.plot(df_pre_concat['Frequency'], df_pre_concat['S11'], color='blue', label='Reconstructed S11')

# Plot the actual S11 in red
plt.plot(df_pre_concat2['Frequency'], df_pre_concat2['Actual'], color='red', label='Actual S11')

# Adding labels, title, and legend
plt.xlabel('Frequency')
plt.ylabel('S11')
plt.title('Line Graph of Reconstructed and Actual S11')
plt.legend()  # Show legend
plt.grid(True)
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1471], line 6
#       3 new_data = x_data[random_sample].reshape(1, -1)
#       4 prediction = simulation.predict(scaler_x.transform(new_data))
# ----> 6 prediction = scaler_y.inverse_transform(prediction)
#       7 # The 'predictions' variable will contain the predicted outputs for your new data
#       8 # print(prediction)
#      10 yf=np.squeeze(yf_data[:len(df_yst.columns)])
#
# File ~\AppData\Local\anaconda3\envs\Quantum\lib\site-packages\sklearn\preprocessing\_data.py:548, in MinMaxScaler.inverse_transform(self, X)
#     542 check_is_fitted(self)
#     544 X = check_array(
#     545     X, copy=self.copy, dtype=FLOAT_DTYPES, force_all_finite="allow-nan"
#     546 )
# --> 548 X -= self.min_
#     549 X /= self.scale_
#     550 return X
#
# ValueError: operands could not be broadcast together with shapes (1,250) (170,) (1,250)

# %%
# # Plotting
# plt.figure(figsize=(10, 6))

# # Plot the first line (S11)
# plt.plot(df_pre_concat['Frequency'], df_pre_concat['S11'], marker='o', linestyle='-', color='b', label='Predicted S11')

# # Plot the second line (Actual)
# plt.plot(df_pre_concat2['Frequency'], df_pre_concat2['Actual'], marker='x', linestyle='--', color='r', label='Actual S11')

# # Adding labels, title, and legend
# plt.xlabel('Frequency')
# plt.ylabel('S11')
# plt.title('Line Graph of Predicted and Actual S11')
# plt.legend()  # Show legend
# plt.grid(True)
# plt.show()
